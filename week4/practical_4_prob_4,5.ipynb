# %%
import pandas as pd
pd.set_option("max_colwidth", 12)

# %%
#4
df = pd.read_csv("netflix_titles.csv")

# %%
df["cast"] = df["cast"].astype("str").str.split(",")

# %%
df.explode("cast")
# Out:
#        show_id     type        title     director         cast      country  \
# 0     81145628    Movie  Norm of ...  Richard ...  Alan Mar...  United S...
# 0     81145628    Movie  Norm of ...  Richard ...   Andrew ...  United S...
# 0     81145628    Movie  Norm of ...  Richard ...   Brian D...  United S...
# 0     81145628    Movie  Norm of ...  Richard ...   Cole Ho...  United S...
# 0     81145628    Movie  Norm of ...  Richard ...   Jennife...  United S...
# ...        ...      ...          ...          ...          ...          ...
# 6233  70153404  TV Show      Friends          NaN   Courten...  United S...
# 6233  70153404  TV Show      Friends          NaN   Lisa Ku...  United S...
# 6233  70153404  TV Show      Friends          NaN   Matt Le...  United S...
# 6233  70153404  TV Show      Friends          NaN   Matthew...  United S...
# 6233  70153404  TV Show      Friends          NaN   David S...  United S...
#
# ...

# %%
#5
import matplotlib.pyplot as plt
def duration_fix(x):
    return x.split()[0]

df["duration"] = df["duration"].apply(duration_fix)

df["date_added"] = pd.to_datetime(df["date_added"])

df = df[df["cast"].astype("str").str.contains("Antonio Banderas")].sort_values(by = "date_added")


plt.plot(df["date_added"],df["duration"].astype("int"))
